# %%
import cv2
import torch

import numpy as np

from PIL import Image
from torchvision import transforms

model = torch.hub.load('facebookresearch/deit:main', 'deit_tiny_patch16_224', pretrained=True)

transform = transforms.Compose([
    transforms.Resize((224, 224)),
    transforms.ToTensor(),
    transforms.Normalize(mean=[0.5, 0.5, 0.5], std=[0.5, 0.5, 0.5]),
])

img = Image.open('/home/kist/franka_panda_3_mppi/src/vit_explain/examples/both.png')
img.resize((224, 224))
input_tensor = transform(img).unsqueeze(0).cuda()
print(input_tensor.size())

if torch.cuda.is_available():
    input_tensor = input_tensor.cuda()
    model = model.cuda()
    
print("Successed!")
# Out:
# torch.Size([1, 3, 224, 224])
# Successed!
# Using cache found in /home/kist/.cache/torch/hub/facebookresearch_deit_main

# %%
def rollout(attentions, discatd_ratio, head_fusion):
    print('attention_size:', attentions.size())
    '''
    attentions: [1, 3, 197, 197] size의 tensor가 12개 담긴 list
    '''
    result = torch.eye(attentions[0].size(-1)).cuda()
    
    with torch.no_grad():
        for attention in attentions:
            if head_fusion == 'mean':
                attention_heads_fused = attention.mean(axis=1)
            elif head_fusion == 'max':
                attention_heads_fused = attention.max(axis=1)[0]
            elif head_fusion == 'min':
                attention_heads_fused = attention.min(axis=1)[0]
            else:
                raise 'Attention head fusion type Not supported'
            
            # Drop the lowest attentions, but don't drop the class token
            flat = attention_heads_fused.view(attention_heads_fused.size(0), -1)
            _, indices = flat.topk(int(flat.size(-1)*discatd_ratio), dim = -1, largest = False)
            indices = indices[indices != 0]
            flat[0, indices] = 0
            
            I = torch.eye(attention_heads_fused.size(-1)).cuda()
            a = (attention_heads_fused + 1.0 * I) / 2
            a = a / a.sum(dim = -1)
            
            result = torch.matmul(a, result) # [1, 197, 197]
            
    # look at the total attention between the class token,
    # and the image patches
    mask = result[0,0,1:] # [196, 196]
    
    # in case of 224 x 224 image, this brings us from 196 to 14
    width = int(mask.size(-1)**0.5)
    mask = mask.reshape(width, width).cpu().numpy()
    mask = mask / np.max(mask)
    return mask # [14, 14]

class ViTAttentionRollout:
    def __init__(self, model, attention_layer_name='attn', head_fusion='mean', discard_ratio=0.9):
        self.model = model
        self.head_fusion = head_fusion
        self.discard_ratio = discard_ratio
        
        for name, module in self.model.named_modules():
            print('name:',name)
            if attention_layer_name in name and isinstance(module, torch.nn.Module):
                module.register_forward_hook(self.get_attention)
                print(f"Hook registered for : {name}")
                
        self.attentions = []
        
    def get_attention(self, module, input, output):
        print(f"Hook called for {module}")
        self.attentions.append(output.cpu())
        
    def __call__(self, input_tensor):
        self.attentions = []
        
        with torch.no_grad():
            output = self.model(input_tensor)
            
        if not self.attentions:
            raise RuntimeError("No attentions were collected. Check the attention layer name and forward hook.")
        
        return rollout(self.attentions, self.discard_ratio, self.head_fusion)
    
def show_mask_on_image(img, mask):
    img = np.float32(img) / 255
    heatmap = cv2.applyColorMap(np.uint8(255 * mask), cv2.COLORMAP_JET)
    heatmap = np.float32(heatmap) / 255
    cam = heatmap + np.float32(img)
    cam = cam / np.max(cam)
    return np.uint8(255 * cam)

# %%
model = torch.hub.load('facebookresearch/deit:main', 'deit_tiny_patch16_224', pretrained=True)
if torch.cuda.is_available():
    model = model.cuda()
# model.eval()
# Out:
# Using cache found in /home/kist/.cache/torch/hub/facebookresearch_deit_main

# %%
rollout = ViTAttentionRollout(model, discard_ratio=0.9, head_fusion='max')
# _, mask = rollout(input_tensor)

print("HERE:\n", rollout.attentions)
# Out:
# name:
# name: patch_embed
# name: patch_embed.proj
# name: patch_embed.norm
# name: pos_drop
# name: patch_drop
# name: norm_pre
# name: blocks
# name: blocks.0
# name: blocks.0.norm1
# name: blocks.0.attn
# Hook registered for : blocks.0.attn
# name: blocks.0.attn.qkv
# Hook registered for : blocks.0.attn.qkv
# name: blocks.0.attn.q_norm
# Hook registered for : blocks.0.attn.q_norm
# name: blocks.0.attn.k_norm
# Hook registered for : blocks.0.attn.k_norm
# name: blocks.0.attn.attn_drop
# Hook registered for : blocks.0.attn.attn_drop
# name: blocks.0.attn.proj
# Hook registered for : blocks.0.attn.proj
# name: blocks.0.attn.proj_drop
# Hook registered for : blocks.0.attn.proj_drop
# name: blocks.0.ls1
# name: blocks.0.drop_path1
# name: blocks.0.norm2
# name: blocks.0.mlp
# name: blocks.0.mlp.fc1
# name: blocks.0.mlp.act
# name: blocks.0.mlp.drop1
# name: blocks.0.mlp.norm
# name: blocks.0.mlp.fc2
# name: blocks.0.mlp.drop2
# name: blocks.0.ls2
# name: blocks.0.drop_path2
# name: blocks.1
# name: blocks.1.norm1
# name: blocks.1.attn
# Hook registered for : blocks.1.attn
# name: blocks.1.attn.qkv
# Hook registered for : blocks.1.attn.qkv
# name: blocks.1.attn.q_norm
# Hook registered for : blocks.1.attn.q_norm
# name: blocks.1.attn.k_norm
# Hook registered for : blocks.1.attn.k_norm
# name: blocks.1.attn.attn_drop
# Hook registered for : blocks.1.attn.attn_drop
# name: blocks.1.attn.proj
# Hook registered for : blocks.1.attn.proj
# name: blocks.1.attn.proj_drop
# Hook registered for : blocks.1.attn.proj_drop
# name: blocks.1.ls1
# name: blocks.1.drop_path1
# name: blocks.1.norm2
# name: blocks.1.mlp
# name: blocks.1.mlp.fc1
# name: blocks.1.mlp.act
# name: blocks.1.mlp.drop1
# name: blocks.1.mlp.norm
# name: blocks.1.mlp.fc2
# name: blocks.1.mlp.drop2
# name: blocks.1.ls2
# name: blocks.1.drop_path2
# name: blocks.2
# name: blocks.2.norm1
# name: blocks.2.attn
# Hook registered for : blocks.2.attn
# name: blocks.2.attn.qkv
# Hook registered for : blocks.2.attn.qkv
# name: blocks.2.attn.q_norm
# Hook registered for : blocks.2.attn.q_norm
# name: blocks.2.attn.k_norm
# Hook registered for : blocks.2.attn.k_norm
# name: blocks.2.attn.attn_drop
# Hook registered for : blocks.2.attn.attn_drop
# name: blocks.2.attn.proj
# Hook registered for : blocks.2.attn.proj
# name: blocks.2.attn.proj_drop
# Hook registered for : blocks.2.attn.proj_drop
# name: blocks.2.ls1
# name: blocks.2.drop_path1
# name: blocks.2.norm2
# name: blocks.2.mlp
# name: blocks.2.mlp.fc1
# name: blocks.2.mlp.act
# name: blocks.2.mlp.drop1
# name: blocks.2.mlp.norm
# name: blocks.2.mlp.fc2
# name: blocks.2.mlp.drop2
# name: blocks.2.ls2
# name: blocks.2.drop_path2
# name: blocks.3
# name: blocks.3.norm1
# name: blocks.3.attn
# Hook registered for : blocks.3.attn
# name: blocks.3.attn.qkv
# Hook registered for : blocks.3.attn.qkv
# name: blocks.3.attn.q_norm
# Hook registered for : blocks.3.attn.q_norm
# name: blocks.3.attn.k_norm
# Hook registered for : blocks.3.attn.k_norm
# name: blocks.3.attn.attn_drop
# Hook registered for : blocks.3.attn.attn_drop
# name: blocks.3.attn.proj
# Hook registered for : blocks.3.attn.proj
# name: blocks.3.attn.proj_drop
# Hook registered for : blocks.3.attn.proj_drop
# name: blocks.3.ls1
# name: blocks.3.drop_path1
# name: blocks.3.norm2
# name: blocks.3.mlp
# name: blocks.3.mlp.fc1
# name: blocks.3.mlp.act
# name: blocks.3.mlp.drop1
# name: blocks.3.mlp.norm
# name: blocks.3.mlp.fc2
# name: blocks.3.mlp.drop2
# name: blocks.3.ls2
# name: blocks.3.drop_path2
# name: blocks.4
# name: blocks.4.norm1
# name: blocks.4.attn
# Hook registered for : blocks.4.attn
# name: blocks.4.attn.qkv
# Hook registered for : blocks.4.attn.qkv
# name: blocks.4.attn.q_norm
# Hook registered for : blocks.4.attn.q_norm
# name: blocks.4.attn.k_norm
# Hook registered for : blocks.4.attn.k_norm
# name: blocks.4.attn.attn_drop
# Hook registered for : blocks.4.attn.attn_drop
# name: blocks.4.attn.proj
# Hook registered for : blocks.4.attn.proj
# name: blocks.4.attn.proj_drop
# Hook registered for : blocks.4.attn.proj_drop
# name: blocks.4.ls1
# name: blocks.4.drop_path1
# name: blocks.4.norm2
# name: blocks.4.mlp
# name: blocks.4.mlp.fc1
# name: blocks.4.mlp.act
# name: blocks.4.mlp.drop1
# name: blocks.4.mlp.norm
# name: blocks.4.mlp.fc2
# name: blocks.4.mlp.drop2
# name: blocks.4.ls2
# name: blocks.4.drop_path2
# name: blocks.5
# name: blocks.5.norm1
# name: blocks.5.attn
# Hook registered for : blocks.5.attn
# name: blocks.5.attn.qkv
# Hook registered for : blocks.5.attn.qkv
# name: blocks.5.attn.q_norm
# Hook registered for : blocks.5.attn.q_norm
# name: blocks.5.attn.k_norm
# Hook registered for : blocks.5.attn.k_norm
# name: blocks.5.attn.attn_drop
# Hook registered for : blocks.5.attn.attn_drop
# name: blocks.5.attn.proj
# Hook registered for : blocks.5.attn.proj
# name: blocks.5.attn.proj_drop
# Hook registered for : blocks.5.attn.proj_drop
# name: blocks.5.ls1
# name: blocks.5.drop_path1
# name: blocks.5.norm2
# name: blocks.5.mlp
# name: blocks.5.mlp.fc1
# name: blocks.5.mlp.act
# name: blocks.5.mlp.drop1
# name: blocks.5.mlp.norm
# name: blocks.5.mlp.fc2
# name: blocks.5.mlp.drop2
# name: blocks.5.ls2
# name: blocks.5.drop_path2
# name: blocks.6
# name: blocks.6.norm1
# name: blocks.6.attn
# Hook registered for : blocks.6.attn
# name: blocks.6.attn.qkv
# Hook registered for : blocks.6.attn.qkv
# name: blocks.6.attn.q_norm
# Hook registered for : blocks.6.attn.q_norm
# name: blocks.6.attn.k_norm
# Hook registered for : blocks.6.attn.k_norm
# name: blocks.6.attn.attn_drop
# Hook registered for : blocks.6.attn.attn_drop
# name: blocks.6.attn.proj
# Hook registered for : blocks.6.attn.proj
# name: blocks.6.attn.proj_drop
# Hook registered for : blocks.6.attn.proj_drop
# name: blocks.6.ls1
# name: blocks.6.drop_path1
# name: blocks.6.norm2
# name: blocks.6.mlp
# name: blocks.6.mlp.fc1
# name: blocks.6.mlp.act
# name: blocks.6.mlp.drop1
# name: blocks.6.mlp.norm
# name: blocks.6.mlp.fc2
# name: blocks.6.mlp.drop2
# name: blocks.6.ls2
# name: blocks.6.drop_path2
# name: blocks.7
# name: blocks.7.norm1
# name: blocks.7.attn
# Hook registered for : blocks.7.attn
# name: blocks.7.attn.qkv
# Hook registered for : blocks.7.attn.qkv
# name: blocks.7.attn.q_norm
# Hook registered for : blocks.7.attn.q_norm
# name: blocks.7.attn.k_norm
# Hook registered for : blocks.7.attn.k_norm
# name: blocks.7.attn.attn_drop
# Hook registered for : blocks.7.attn.attn_drop
# name: blocks.7.attn.proj
# Hook registered for : blocks.7.attn.proj
# name: blocks.7.attn.proj_drop
# Hook registered for : blocks.7.attn.proj_drop
# name: blocks.7.ls1
# name: blocks.7.drop_path1
# name: blocks.7.norm2
# name: blocks.7.mlp
# name: blocks.7.mlp.fc1
# name: blocks.7.mlp.act
# name: blocks.7.mlp.drop1
# name: blocks.7.mlp.norm
# name: blocks.7.mlp.fc2
# name: blocks.7.mlp.drop2
# name: blocks.7.ls2
# name: blocks.7.drop_path2
# name: blocks.8
# name: blocks.8.norm1
# name: blocks.8.attn
# Hook registered for : blocks.8.attn
# name: blocks.8.attn.qkv
# Hook registered for : blocks.8.attn.qkv
# name: blocks.8.attn.q_norm
# Hook registered for : blocks.8.attn.q_norm
# name: blocks.8.attn.k_norm
# Hook registered for : blocks.8.attn.k_norm
# name: blocks.8.attn.attn_drop
# Hook registered for : blocks.8.attn.attn_drop
# name: blocks.8.attn.proj
# Hook registered for : blocks.8.attn.proj
# name: blocks.8.attn.proj_drop
# Hook registered for : blocks.8.attn.proj_drop
# name: blocks.8.ls1
# name: blocks.8.drop_path1
# name: blocks.8.norm2
# name: blocks.8.mlp
# name: blocks.8.mlp.fc1
# name: blocks.8.mlp.act
# name: blocks.8.mlp.drop1
# name: blocks.8.mlp.norm
# name: blocks.8.mlp.fc2
# name: blocks.8.mlp.drop2
# name: blocks.8.ls2
# name: blocks.8.drop_path2
# name: blocks.9
# name: blocks.9.norm1
# name: blocks.9.attn
# Hook registered for : blocks.9.attn
# name: blocks.9.attn.qkv
# Hook registered for : blocks.9.attn.qkv
# name: blocks.9.attn.q_norm
# Hook registered for : blocks.9.attn.q_norm
# name: blocks.9.attn.k_norm
# Hook registered for : blocks.9.attn.k_norm
# name: blocks.9.attn.attn_drop
# Hook registered for : blocks.9.attn.attn_drop
# name: blocks.9.attn.proj
# Hook registered for : blocks.9.attn.proj
# name: blocks.9.attn.proj_drop
# Hook registered for : blocks.9.attn.proj_drop
# name: blocks.9.ls1
# name: blocks.9.drop_path1
# name: blocks.9.norm2
# name: blocks.9.mlp
# name: blocks.9.mlp.fc1
# name: blocks.9.mlp.act
# name: blocks.9.mlp.drop1
# name: blocks.9.mlp.norm
# name: blocks.9.mlp.fc2
# name: blocks.9.mlp.drop2
# name: blocks.9.ls2
# name: blocks.9.drop_path2
# name: blocks.10
# name: blocks.10.norm1
# name: blocks.10.attn
# Hook registered for : blocks.10.attn
# name: blocks.10.attn.qkv
# Hook registered for : blocks.10.attn.qkv
# name: blocks.10.attn.q_norm
# Hook registered for : blocks.10.attn.q_norm
# name: blocks.10.attn.k_norm
# Hook registered for : blocks.10.attn.k_norm
# name: blocks.10.attn.attn_drop
# Hook registered for : blocks.10.attn.attn_drop
# name: blocks.10.attn.proj
# Hook registered for : blocks.10.attn.proj
# name: blocks.10.attn.proj_drop
# Hook registered for : blocks.10.attn.proj_drop
# name: blocks.10.ls1
# name: blocks.10.drop_path1
# name: blocks.10.norm2
# name: blocks.10.mlp
# name: blocks.10.mlp.fc1
# name: blocks.10.mlp.act
# name: blocks.10.mlp.drop1
# name: blocks.10.mlp.norm
# name: blocks.10.mlp.fc2
# name: blocks.10.mlp.drop2
# name: blocks.10.ls2
# name: blocks.10.drop_path2
# name: blocks.11
# name: blocks.11.norm1
# name: blocks.11.attn
# Hook registered for : blocks.11.attn
# name: blocks.11.attn.qkv
# Hook registered for : blocks.11.attn.qkv
# name: blocks.11.attn.q_norm
# Hook registered for : blocks.11.attn.q_norm
# name: blocks.11.attn.k_norm
# Hook registered for : blocks.11.attn.k_norm
# name: blocks.11.attn.attn_drop
# Hook registered for : blocks.11.attn.attn_drop
# name: blocks.11.attn.proj
# Hook registered for : blocks.11.attn.proj
# name: blocks.11.attn.proj_drop
# Hook registered for : blocks.11.attn.proj_drop
# name: blocks.11.ls1
# name: blocks.11.drop_path1
# name: blocks.11.norm2
# name: blocks.11.mlp
# name: blocks.11.mlp.fc1
# name: blocks.11.mlp.act
# name: blocks.11.mlp.drop1
# name: blocks.11.mlp.norm
# name: blocks.11.mlp.fc2
# name: blocks.11.mlp.drop2
# name: blocks.11.ls2
# name: blocks.11.drop_path2
# name: norm
# name: fc_norm
# name: head_drop
# name: head
# HERE:
#  []

# %%
np_img = np.array(img)[:, :, ::-1]
mask = cv2.resize(mask, (np_img.shape[1], np_img.shape[0]))
mask = show_mask_on_image(np_img, mask)

cv2.imshow("Attention Rollout", mask)
cv2.waitKey(0)
cv2.destroyAllWindows()
